# %%
# import library
import os
import shutil
import matplotlib.pyplot as plt
import shutil

# %%
# Hitung jumlah paragraf dari setiap karya ilmiah dari file asli
directory_path_real = '/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap7(DataCleaning)'

files_real = os.listdir(directory_path_real)
list_files_real = []
list_num_of_paragraph_real = []

# Ambil daftar nama file
for file in files_real:
    if '.DS_Store' not in file:
        list_files_real.append(file)
        
all_text_real = ""
for file in list_files_real:
    with open('/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap7(DataCleaning)/' + file, 'r') as fileNow:
        content = fileNow.read()
        lines = content.splitlines()
        list_num_of_paragraph_real.append(len(lines))
        if len(lines) > 300:
            print(file)
# Out:
# Formal-Verification-based-on-Boolean-E_2001_Electronic-Notes-in-Theoretical-.txt
# Types-for-Modules_2004_Electronic-Notes-in-Theoretical-Computer-Science.txt

# %%
# Hitung jumlah paragraf dari setiap karya ilmiah dari file parafrasa
directory_path_paraphrased = '/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap9(ParaphrasedPaper)'

files_paraphrased = os.listdir(directory_path_paraphrased)
list_files_paraphrased = []
list_num_of_paragraph_paraphrased = []

# Ambil daftar nama file
for file in files_paraphrased:
    if '.DS_Store' not in file:
        list_files_paraphrased.append(file)
        
all_text_paraphrased = ""
for file in list_files_paraphrased:
    with open('/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap9(ParaphrasedPaper)/' + file, 'r') as fileNow:
        content = fileNow.read()
        lines = content.splitlines()
        list_num_of_paragraph_paraphrased.append(len(lines))

# %%
# Membuat visualisasi histogram untuk jumlah paragraf dari file asli

plt.hist(list_num_of_paragraph_real, edgecolor='black')  
plt.xlabel('Banyak Paragraf')
plt.ylabel('Frekuensi')
plt.title('Histogram Untuk Banyak Paragrap untuk File Asli')
plt.grid(True)
plt.show()

# %%
# Membuat visualisasi histogram untuk jumlah paragraf dari file parafrasa

plt.hist(list_num_of_paragraph_paraphrased, edgecolor='black')  
plt.xlabel('Banyak Paragraf')
plt.ylabel('Frekuensi')
plt.title('Histogram Untuk Banyak Paragrap untuk File Parafrasa')
plt.grid(True)
plt.show()

# %%
# buang jumlah karya tulis ilmiah yang memiliki jumlah paragraf lebih dari 100

# buang dari list file asli
list_num_of_paragraph_real = [x for x in list_num_of_paragraph_real if x < 100]

# buang dari list file parafrasa
list_num_of_paragraph_paraphrased = [x for x in list_num_of_paragraph_paraphrased if x < 100]

# %%
# Membuat visualisasi histogram untuk jumlah paragraf dari file asli untuk jumlah paragraf kurang dari 100

plt.hist(list_num_of_paragraph_real, edgecolor='black')  
plt.xlabel('Banyak Paragraf')
plt.ylabel('Frekuensi')
plt.title('Histogram Untuk Banyak Paragrap untuk File Asli')
plt.grid(True)
plt.show()

# %%
# Ambil file asli sebanyak 1000 yang memiliki jumlah paragraf 10-20 (kalo cmn ambil sampau 15 cmn ada 341 file)
directory_path_real = '/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap7(DataCleaning)'

files_real = os.listdir(directory_path_real)
list_files_real = []
counter = 0

# Ambil daftar nama file
for file in files_real:
    if '.DS_Store' not in file:
        list_files_real.append(file)
        
all_text_real = ""
for file in list_files_real:
    with open('/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap7(DataCleaning)/' + file, 'r') as fileNow:
        content = fileNow.read()
        lines = content.splitlines()
        if len(lines) >= 10 and len(lines) <= 20 and counter < 1000:
            counter += 1
            # sumber file
            source_file = '/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap7(DataCleaning)/' + file
            
            # file tujuan
            destination_folder = '/Users/williamnehemia/Documents/Skripsi/TugasAkhir/WordEmbeddingModel/Data/Data_asli'
            
            # menyalin file ke folder baru
            shutil.copy(source_file, destination_folder)

# %%
# Ambil file parafrasa sebanyak 1000 yang memiliki jumlah paragraf 10-20
directory_path_paraphrased = '/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap9(ParaphrasedPaper)'

files_paraphrased = os.listdir(directory_path_paraphrased)
list_files_paraphrased = []
counter = 0

# Ambil daftar nama file
for file in files_paraphrased:
    if '.DS_Store' not in file:
        list_files_paraphrased.append(file)
        
all_text_paraphrased = ""
for file in list_files_paraphrased:
    with open('/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap9(ParaphrasedPaper)/' + file, 'r') as fileNow:
        content = fileNow.read()
        lines = content.splitlines()
        if len(lines) >= 10 and len(lines) <= 20 and counter < 1000:
            counter += 1
            # sumber file
            source_file = '/Users/williamnehemia/Documents/Skripsi/TugasAkhir/DataPreprocessing/DataTahap9(ParaphrasedPaper)/' + file
            
            # file tujuan
            destination_folder = '/Users/williamnehemia/Documents/Skripsi/TugasAkhir/WordEmbeddingModel/Data/Data_parafrasa'
            
            # menyalin file ke folder baru
            shutil.copy(source_file, destination_folder)
